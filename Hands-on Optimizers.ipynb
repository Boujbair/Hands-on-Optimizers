# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# (60000, 28, 28) (60000,)

# %%
x_train= x_train.reshape(x_train.shape[0],28,28,1)
x_test=  x_test.reshape(x_test.shape[0],28,28,1)
input_shape=(28,28,1)
y_train=keras.utils.to_categorical(y_train)#,num_classes=)
y_test=keras.utils.to_categorical(y_test)#, num_classes)
x_train= x_train.astype('float32')
x_test= x_test.astype('float32')
x_train /= 255
x_test /=255

# %%
batch_size=64

num_classes=10

epochs=10

def build_model(optimizer):

  model=Sequential()

  model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=input_shape))

  model.add(MaxPooling2D(pool_size=(2,2)))

  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256, activation='relu'))

  model.add(Dropout(0.5))

  model.add(Dense(num_classes, activation='softmax'))

  model.compile(loss=keras.losses.categorical_crossentropy, optimizer= optimizer, metrics=['accuracy'])

  return model

# %%
optimizers = ['Adadelta', 'Adagrad', 'Adam', 'RMSprop', 'SGD']

for i in optimizers:

  model = build_model(i)

  hist=model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 64s 67ms/step - loss: 2.2573 - accuracy: 0.1713 - val_loss: 2.1737 - val_accuracy: 0.4255
# Epoch 2/10
# 938/938 [==============================] - 59s 63ms/step - loss: 2.1305 - accuracy: 0.3446 - val_loss: 2.0288 - val_accuracy: 0.6395
# Epoch 3/10
# 938/938 [==============================] - 73s 78ms/step - loss: 1.9919 - accuracy: 0.4884 - val_loss: 1.8667 - val_accuracy: 0.7247
# Epoch 4/10
# 938/938 [==============================] - 59s 63ms/step - loss: 1.8373 - accuracy: 0.5808 - val_loss: 1.6923 - val_accuracy: 0.7652
# Epoch 5/10
# 938/938 [==============================] - 59s 63ms/step - loss: 1.6800 - accuracy: 0.6365 - val_loss: 1.5176 - val_accuracy: 0.7851
# Epoch 6/10
# 938/938 [==============================] - 61s 66ms/step - loss: 1.5232 - accuracy: 0.6706 - val_loss: 1.3532 - val_accuracy: 0.8025
# Epoch 7/10
# 938/938 [==============================] - 64s 68ms/step - loss: 1.3791 - accuracy: 0.6943 - val_loss: 1.2053 - val_accuracy: 0.8134
# Epoch 8/10
# 938/938 [==============================] - 69s 74ms/step - loss: 1.2507 - accuracy: 0.7143 - val_loss: 1.0767 - val_accuracy: 0.8238
# Epoch 9/10
# 938/938 [==============================] - 68s 73ms/step - loss: 1.1442 - accuracy: 0.7298 - val_loss: 0.9680 - val_accuracy: 0.8330
# Epoch 10/10
# 938/938 [==============================] - 66s 70ms/step - loss: 1.0523 - accuracy: 0.7428 - val_loss: 0.8783 - val_accuracy: 0.8403
# Epoch 1/10
# 938/938 [==============================] - 69s 72ms/step - loss: 1.6738 - accuracy: 0.5358 - val_loss: 0.8720 - val_accuracy: 0.8302
# Epoch 2/10
# 938/938 [==============================] - 60s 64ms/step - loss: 0.7992 - accuracy: 0.7765 - val_loss: 0.5054 - val_accuracy: 0.8798
# Epoch 3/10
# 938/938 [==============================] - 60s 64ms/step - loss: 0.5954 - accuracy: 0.8268 - val_loss: 0.4060 - val_accuracy: 0.8966
# Epoch 4/10
# 938/938 [==============================] - 60s 64ms/step - loss: 0.5190 - accuracy: 0.8475 - val_loss: 0.3612 - val_accuracy: 0.9052
# Epoch 5/10
# 938/938 [==============================] - 58s 62ms/step - loss: 0.4718 - accuracy: 0.8608 - val_loss: 0.3324 - val_accuracy: 0.9101
# Epoch 6/10
# 938/938 [==============================] - 52s 56ms/step - loss: 0.4424 - accuracy: 0.8680 - val_loss: 0.3112 - val_accuracy: 0.9156
# Epoch 7/10
# 938/938 [==============================] - 61s 65ms/step - loss: 0.4164 - accuracy: 0.8781 - val_loss: 0.2946 - val_accuracy: 0.9187
# Epoch 8/10
# 938/938 [==============================] - 59s 63ms/step - loss: 0.3950 - accuracy: 0.8835 - val_loss: 0.2812 - val_accuracy: 0.9222
# Epoch 9/10
# 938/938 [==============================] - 55s 59ms/step - loss: 0.3789 - accuracy: 0.8867 - val_loss: 0.2698 - val_accuracy: 0.9240
# Epoch 10/10
# 938/938 [==============================] - 51s 55ms/step - loss: 0.3674 - accuracy: 0.8912 - val_loss: 0.2596 - val_accuracy: 0.9263
# Epoch 1/10
# 938/938 [==============================] - 55s 57ms/step - loss: 0.2453 - accuracy: 0.9247 - val_loss: 0.0713 - val_accuracy: 0.9773
# Epoch 2/10
# 938/938 [==============================] - 61s 65ms/step - loss: 0.0977 - accuracy: 0.9705 - val_loss: 0.0527 - val_accuracy: 0.9830
# Epoch 3/10
# 938/938 [==============================] - 61s 65ms/step - loss: 0.0723 - accuracy: 0.9777 - val_loss: 0.0441 - val_accuracy: 0.9857
# Epoch 4/10
# 938/938 [==============================] - 60s 64ms/step - loss: 0.0611 - accuracy: 0.9806 - val_loss: 0.0419 - val_accuracy: 0.9862
# Epoch 5/10
# 938/938 [==============================] - 63s 67ms/step - loss: 0.0523 - accuracy: 0.9827 - val_loss: 0.0381 - val_accuracy: 0.9865
# Epoch 6/10
# 938/938 [==============================] - 56s 60ms/step - loss: 0.0448 - accuracy: 0.9855 - val_loss: 0.0346 - val_accuracy: 0.9883
# Epoch 7/10
# 938/938 [==============================] - 52s 56ms/step - loss: 0.0384 - accuracy: 0.9878 - val_loss: 0.0344 - val_accuracy: 0.9879
# Epoch 8/10
# 938/938 [==============================] - 54s 57ms/step - loss: 0.0330 - accuracy: 0.9893 - val_loss: 0.0337 - val_accuracy: 0.9888
# Epoch 9/10
# 938/938 [==============================] - 70s 74ms/step - loss: 0.0314 - accuracy: 0.9898 - val_loss: 0.0351 - val_accuracy: 0.9898
# Epoch 10/10
# 938/938 [==============================] - 64s 68ms/step - loss: 0.0286 - accuracy: 0.9906 - val_loss: 0.0322 - val_accuracy: 0.9896
# Epoch 1/10
# 938/938 [==============================] - 74s 77ms/step - loss: 0.2358 - accuracy: 0.9272 - val_loss: 0.0735 - val_accuracy: 0.9769
# Epoch 2/10
# 938/938 [==============================] - 70s 75ms/step - loss: 0.0942 - accuracy: 0.9719 - val_loss: 0.0530 - val_accuracy: 0.9816
# Epoch 3/10
# 938/938 [==============================] - 71s 76ms/step - loss: 0.0745 - accuracy: 0.9779 - val_loss: 0.0533 - val_accuracy: 0.9817
# Epoch 4/10
# 938/938 [==============================] - 69s 74ms/step - loss: 0.0672 - accuracy: 0.9804 - val_loss: 0.0447 - val_accuracy: 0.9863
# Epoch 5/10
# 938/938 [==============================] - 79s 84ms/step - loss: 0.0662 - accuracy: 0.9813 - val_loss: 0.0454 - val_accuracy: 0.9866
# Epoch 6/10
# 938/938 [==============================] - 99s 105ms/step - loss: 0.0680 - accuracy: 0.9809 - val_loss: 0.0544 - val_accuracy: 0.9828
# Epoch 7/10
# 938/938 [==============================] - 99s 106ms/step - loss: 0.0674 - accuracy: 0.9814 - val_loss: 0.0469 - val_accuracy: 0.9855
# Epoch 8/10
# 938/938 [==============================] - 67s 72ms/step - loss: 0.0692 - accuracy: 0.9815 - val_loss: 0.0488 - val_accuracy: 0.9860
# Epoch 9/10
# 938/938 [==============================] - 66s 71ms/step - loss: 0.0706 - accuracy: 0.9803 - val_loss: 0.0572 - val_accuracy: 0.9829
# Epoch 10/10
# 938/938 [==============================] - 70s 75ms/step - loss: 0.0732 - accuracy: 0.9803 - val_loss: 0.0542 - val_accuracy: 0.9851
# Epoch 1/10
# 938/938 [==============================] - 58s 60ms/step - loss: 0.8351 - accuracy: 0.7464 - val_loss: 0.3098 - val_accuracy: 0.9094
# Epoch 2/10
# 938/938 [==============================] - 65s 69ms/step - loss: 0.3851 - accuracy: 0.8818 - val_loss: 0.2345 - val_accuracy: 0.9320
# Epoch 3/10
# 938/938 [==============================] - 59s 63ms/step - loss: 0.3149 - accuracy: 0.9054 - val_loss: 0.1939 - val_accuracy: 0.9439
# Epoch 4/10
# 938/938 [==============================] - 60s 64ms/step - loss: 0.2732 - accuracy: 0.9175 - val_loss: 0.1659 - val_accuracy: 0.9519
# Epoch 5/10
# 938/938 [==============================] - 71s 75ms/step - loss: 0.2475 - accuracy: 0.9250 - val_loss: 0.1478 - val_accuracy: 0.9558
# Epoch 6/10
# 938/938 [==============================] - 55s 58ms/step - loss: 0.2243 - accuracy: 0.9335 - val_loss: 0.1333 - val_accuracy: 0.9595
# Epoch 7/10
# 938/938 [==============================] - 55s 59ms/step - loss: 0.2060 - accuracy: 0.9391 - val_loss: 0.1240 - val_accuracy: 0.9630
# Epoch 8/10
# 938/938 [==============================] - 61s 65ms/step - loss: 0.1975 - accuracy: 0.9403 - val_loss: 0.1137 - val_accuracy: 0.9657
# Epoch 9/10
# 938/938 [==============================] - 56s 60ms/step - loss: 0.1822 - accuracy: 0.9459 - val_loss: 0.1098 - val_accuracy: 0.9672
# Epoch 10/10
# 938/938 [==============================] - 56s 59ms/step - loss: 0.1745 - accuracy: 0.9470 - val_loss: 0.1034 - val_accuracy: 0.9685
